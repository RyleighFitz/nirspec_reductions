# %%
import numpy as np
import matplotlib.pyplot as plt
from fits_dataclass import Image, ImageSet
import os
import matplotlib.patches as patches

# %%
### Read in Data ###
in_dir = '/Users/ryleighfitzpatrick/TitanMethane/quickanddirty_reduction/O49/'
scam_dir = '/Users/ryleighfitzpatrick/TitanMethane/KeckII_Nirspec/raw_data/20170710/sci/scam/'


# Read in all data (science and calibration spectra)
data = ImageSet([Image.load(in_dir+im) for im in os.listdir(in_dir)])
data = data[1:] #Remove first image (bad exposure)

# Read in scam images (science)
scams = ImageSet([Image.load(scam_dir+im) for im in os.listdir(scam_dir)])

# %%
from scipy import optimize
from skimage import draw, measure

def find_circle(image):
    
    image = image.astype(int)
    regions = measure.regionprops(image)
    bubble = regions[0]

    y0, x0 = bubble.centroid
    r = bubble.major_axis_length / 2.

    def cost(params):
        x0, y0, r = params
        coords = draw.circle(y0, x0, r, shape=image.shape)
        template = np.zeros_like(image)
        template[coords] = 1
        return -np.sum(template == image)

    x0, y0, r = optimize.fmin(cost, (x0, y0, r))
    return x0, y0, r

def plot_circles(ax, center, radius, **kwargs):
    circle = plt.Circle(center, radius, **kwargs)
    ax.add_artist(circle)
    return ax

# %%
bkg = scams[7].data
plt.imshow(scams[10].data-bkg, vmin=0, vmax=1000)

# %%
# %%capture
titan_loc=[]
for s in hr_scams:
    cx,cy,r = find_circle(s.data>800)
    titan_loc.append([(cx, cy), r])

# %%
from datetime import datetime, timedelta

def match_scam(img, scams):
    """Return scam image closest to the middle of the image exposure.
    
    TO DO: Maybe update to return all scam images to check for shift"""
    
    time = datetime.strptime(img.header['DATE-OBS']+' '+img.header['UT'][:8], '%Y-%m-%d %H:%M:%S')+ \
            timedelta(0,img.header['ITIME']/2.) #Halfway through exposure

    return min(scams, key=lambda s:abs(datetime.strptime(s.header['DATE-OBS']+' '+s.header['UT'][:8], '%Y-%m-%d %H:%M:%S') -
                            time))

# %%
#Get HR scams for each spec and subtract bkg scam
hr_scams = [match_scam(d, scams) for d in data]
hr_scams = [Image(_data = scam.data - bkg, header=scam.header) for scam in hr_scams]

#Sort by time
hr_scams = sorted(hr_scams, key=lambda s: s.header['UT']) 
data = sorted(data, key=lambda d: d.header['UT'])

# %%
slit_cen = (hr_scams[10].header['SLITX'], hr_scams[10].header['SLITY'])
alpha = hr_scams[0].header['SLITANG']

# %%
i=0
radius = 25.

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(hr_scams[i].data, vmin=0, vmax=1500)

cen = titan_loc[i][0]
circle = plt.Circle(cen, radius, color='r', fill=None)
ax.add_artist(circle)
ax.plot(slit_cen[0], slit_cen[1], 'r+')

#ax.plot(y1,x1, 'o', color='cyan', markersize=11)
#ax.plot(y2,x2,'o', color='cyan', markersize=11)

# %%
hr_scams[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Mon Jul 10 09:37:55 2017
# BITPIX  =                   32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  256 / Number of pixels in axis 1
# NAXIS2  =                  256 / Number of pixels in axis 2
# BSCALE  =                  1.0 / Scaling factor
# BZERO   =                  0.0 / Scaling zero-point
# TELESCOP= 'Keck II'            / Telescope
# OBSERVER= 'NIRSPEC'            / Observer
# OBJECT  = 'Titan HR Offset 01' / Object name
# COMMENT
# ROOTNAME= 'jul10i'             / File Root Name
# FILENUM2=                   45 / Frame Number
# FILENAME= 'jul10i0045.fits'    / Original File Name
# OUTDIR2 = '/sdata602/nirspec/2017jul10/scam/' / Data Directory
# FILNAME = 'NIRSPEC-5-AO'       / Filter Name
# SLITNAME= '0.041x2.26'         / Slit Name
# SLITPA  =               74.163 / Slit position angle
# SLITX   =                131.5 / X pixel of the center of the slit
# SLITY   =                125.0 / Y pixel of the center of the slit
# SLITANG =                 11.6 / Slit angle in the scam. CCW from hor.
# SCAMPA  =              152.563 / Scam position angle
# ITIME2  =                  5.0 / Integration time per coadd
# COADDS2 =                    1 / Number of coadds
# SAMPMODE=                    2 / 1=Single; 2=CDS; 3=MCDS
# MULTISCA=                    2 / Number of multiple reads
# SAMPRATE=                  250 / Scam sampling rate in KHz
# Q1OFFSET=                  729 / PICNIC Quadrant 1 preamp offset
# Q2OFFSET=                  725 / PICNIC Quadrant 2 preamp offset
# Q3OFFSET=                  724 / PICNIC Quadrant 3 preamp offset
# Q4OFFSET=                  722 / PICNIC Quadrant 4 preamp offset
# CRYOTEMP=                250.4 / PICNIC cold head temperature
# FIL1POS =                   11 / Filter 1 Position
# FIL2POS =                    0 / Filter 2 Position
# SLITPOS =                    6 / Slit Position
# ECHLPOS =                62.69 / Echelle position
# DISPPOS =                36.41 / Cross Disperser position
# IROTLOC =                54000 / Step position of Image rotator
# CALMPOS =                    0 / Cal. Mirror Position, 0=out, 1=in
# CALCPOS =                    0 / Cal. Cover Position, 0=out, 1=in
# CALPPOS =                    0 / Cal. Pinhole Position, 0=out, 1=in
# NEON    =                    0 / Neon lamp: 1=on, 0=off
# ARGON   =                    0 / Argon lamp: 1=on, 0=off
# KRYPTON =                    0 / Krypton lamp: 1=on, 0=off
# XENON   =                    0 / Xenon lamp: 1=on, 0=off
# ETALON  =                    0 / Etalon lamp: 1=on, 0=off
# FLAT    =                    0 / Flat lamp: 1=on, 0=off
# AIRMASS =              1.49563 / air mass (1.50)
# AXESTAT = 'tracking'           / axes control status
# AZ      =            148.77423 / telescope azimuth (148.77 deg)
# CALOCAL =             -0.00037 / collimation azimuth local (-1.
# CELOCAL =             -0.01094 / collimation elevation local (-
# CURRINST= 'NIRSPAO'            / current instrument
# DATE-OBS= '2017-07-10'         / universal date of observation
# DCSSTAT = 'standby'            / drive and control status
# DCSVERS = '7-6-1'              / drive and control version
# DEC     =            -21.89621 / telescope declination (-21:53:
# DOMEPOSN=            148.69428 / dome azimuth (148.69 deg)
# DOMESTAT= 'tracking'           / dome status
# EL      =             41.90335 / telescope elevation (41.90 deg
# EQUINOX =               2000.0 / telescope equinox (2000.0)
# FOCALSTN= 'lnas (left nasmyth' / focal station
# HA      =            -24.58762 / telescope hour angle (+22:21:3
# LST     = '15:50:27.05'        / local apparent sidereal time (
# MJD-OBS =          57944.29081 / modified julian date of observ
# PARANG  =             -31.5912 / parallactic angle astrometric
# PARANTEL=            -31.59771 / parallactic angle telescope (-
# DRA     =                  0.0 / diff ra rate (0.000000 seconds
# DDEC    =                  0.0 / diff decl rate (0.0000000 arcs
# DTRACK  = 'disabled'           / differential tracking enabled
# PONAME  = 'AO scam'            / pointing origin name
# POXOFF  =                  0.0 / pointing origin x offset (0.00
# POYOFF  =                  0.0 / pointing origin y offset (0.00
# POXPOS  =                9e-05 / pointing origin xposition (0.0
# POYPOS  =              0.00142 / pointing origin yposition (1.4
# PONAME1 = 'Opt Axis'           / pointing origin name 1
# POXPOS1 =                  0.0 / pointing origin xposition 1 (0
# POYPOS1 =                  0.0 / pointing origin yposition 1 (0
# PONAME2 = 'AO scam'            / pointing origin name 2
# POXPOS2 =                9e-05 / pointing origin xposition 2 (0
# POYPOS2 =              0.00142 / pointing origin yposition 2 (1
# PONAME3 = 'REF-N'              / pointing origin name 3
# POXPOS3 =               -3e-05 / pointing origin xposition 3 (-
# POYPOS3 =             -0.00198 / pointing origin yposition 3 (-
# PONAME4 = 'TFS'                / pointing origin name 4
# POXPOS4 =              0.02991 / pointing origin xposition 4 (2
# POYPOS4 =             -0.00071 / pointing origin yposition 4 (-
# PONAME5 = 'REF-L'              / pointing origin name 5
# POXPOS5 =              0.00012 / pointing origin xposition 5 (0
# POYPOS5 =             -0.00153 / pointing origin yposition 5 (-
# PONAME6 = 'USER1'              / pointing origin name 6
# POXPOS6 =              0.00044 / pointing origin xposition 6 (0
# POYPOS6 =               0.0016 / pointing origin yposition 6 (1
# PONAME7 = 'USER2'              / pointing origin name 7
# POXPOS7 =              0.00044 / pointing origin xposition 7 (0
# POYPOS7 =               -0.001 / pointing origin yposition 7 (-
# PONAME8 = '<udf>'              / pointing origin name 8
# POXPOS8 =                  0.0 / pointing origin xposition 8 (0
# POYPOS8 =                  0.0 / pointing origin yposition 8 (0
# PONAME9 = '<udf>'              / pointing origin name 9
# RA      =            261.93407 / telescope right ascension (17:
# ROTCALAN=                  0.0 / rotator calibration angle (0.0
# ROTMODE = 'position angle'     / rotator tracking mode
# ROTPPOSN=             62.56041 / rotator physical position (62.
# ROTPOSN =               -10.94 / rotator user position (-10.94
# ROTREFAN=                  0.0 / rotator reference angle (0.00
# SECFOCUS=              0.00024 / secondary mirror focus raw (0.
# SECTHETX=               -5e-05 / secondary mirror thetax (-10.6
# SECTHETY=             -0.00089 / secondary mirror thetay (-184.
# TARGDEC =             -21.8965 / target declination (-21:53:47.
# TARGEPOC=               2000.0 / target epoch (2000.000000)
# TARGEQUI=               2000.0 / target equinox (2000.000000)
# TARGFRAM= 'FK5'                / target frame
# TARGNAME= 'Titan6:40'          / target name
# TARGPLAX=                  0.0 / target parallax (0.0 arcsec)
# TARGPMDC=                  0.0 / target proper motion dec (0.00
# TARGPMRA=                  0.0 / target proper motion ra (0.000
# TARGRA  =            261.93308 / target right ascension (17:27:
# TARGRADV=                  0.0 / target radial velocity (0.0000
# TELFOCUS=              0.00102 / telescope focus compensated (1
# TUBETEMP=               3.7698 / tube temperature (3.77 degC)
# AOOPSMOD= '0'                  / AO General Ops Mode FITS
# AODMSTAT= 'closed'             / AO deformable mirror loop stat
# AODTSTAT= 'closed'             / AO downlink tip/tilt loop stat
# AOTTMODE= 'closed'             / AO tip/tilt offloading mode
# AOAOAMED= '1029'               / AO WFC AOA camera median light
# AOLBFWHM= '0.634952'           / AO LBWFS avg fwhm
# WSFRRT  = '1054'               / Frame rate for WFS cam (Hz)
# DMGAIN  = '0.500'              / Set DM loop gain
# DMMRFN  = '10Jul0012.mr'       / Name of DM reconstructor file
# DTGAIN  = '0.300'              / Set TT loop gain
# AOWFC0  = '-2.999000'          / AO WFS focus stage FSM coeffic
# AOFCNGFO= '-0.003006'          / AO FC NGS Focus Calc Value (m)
# AOFCLGFO= '0.171203'           / AO FC LGS pregain focus calc v
# AOFCLBFO= '0.000000'           / AO FC LBWFS pregain focus calc
# AOFCNGCT= 'ON'                 / AO FC NGS control
# AOFCLGCT= 'OFF'                / AO FC LGS control
# AOFCLBCT= 'OFF'                / AO FC LBWFS control
# AOFCSALT= '86952'              / AO FC sodium alt preset (m)
# AOFOMODE= 'closed'             / AO focus offloading mode
# AOTSDAR = 'false'              / AO TSS_USE_DAR?
# AODRDTEN= '1.0'                / AO DAR DTT CTRLOFF ENABLE
# AODRENA = '1.0'                / AO DAR_ENABLE/DISABLE
# AOTSZ   = '-0.001'             / AO tip/tilt sensor stage Z pos
# AOTSX   = '29.914'             / AO tip/tilt sensor stage X pos
# AOTSY   = '-0.706'             / AO tip/tilt sensor stage Y pos
# OBTSNAME= 'home'               / Named position control for TSS
# OBTSX   = '0.00'               / User value of TSS x axis (mm)
# OBTSY   = '-0.00'              / User value of TSS y axis (mm)
# OBTSZ   = '-0.00'              / User value of TSS z axis (mm)
# AOLPMOVE= 'false'              / AO LSP MOVE ENABLE
# LGRMSWF = '300.0'              / LGSAO RMS WF Residual
# LSAMPPWR= 'null'               / CA connection failed
# LSPROP  = 'null'               / CA connection failed
# AOFMX   = '-0.18'              / AO field steering mirrors X po
# AOFMY   = '1.10'               / AO field steering mirrors Y po
# OBFMXIM = '1.096'              / Image plane x motion for FSM (
# OBFMYIM = '-0.182'             / Image plane y motion for FSM (
# OBFMXPU = '0.00'               / Pupil plane x motion for FSM (
# OBFMYPU = '0.00'               / Pupil plane y motion for FSM (
# OBFMDREN= '1.000000'           / FSM Coordinated move use dar o
# OBFSNAME= '2.4'                / Named position control for FSS
# OBIMNAME= 'in'                 / Named position control for ISM
# OBLBNAME= 'noName'             / Named position control for LBS
# OBAMNAME= 'mirror'             / Named position control for AFM
# OBRT    = '31.2760'            / User value of ROT (deg)
# OBSDNAME= 'beamSplitter'       / Named position control for SOD
# OBSFX   = '-118.99'            / User value of SFP x axis (mm)
# OBSFY   = '-0.00'              / User value of SFP y axis (mm)
# OBSFZ   = '0.00'               / User value of SFP z axis (mm)
# OBSI    = '-1.50'              / User value of SFD (mm)
# OBSFNAME= 'telescope'          / Named position control for SFP
# OBSNNAME= 'block'              / Named position control for SND
# OBWCNAME= '2.4'                / Named position control for WCS
# OBWFSTST= 'INPOS'              / State of FCS as string
# OBWLNAME= '2.4'                / Named position control for WLS
# OBWPNAME= 'ngs'                / Named position control for WPS
# OBWNNAME= 'open'               / Named position control for WND
# OBSWSTA = 'off'                / White light power status
# OBSWNAME= 'BLOCK'              / Named position control for SFW
# OBWF    = '-3.011'             / User value of FCS (mm)
# WSSMPRG = '2'                  / WFS_SciMeas program (0)
# WSSMREP = '561'                / WFS SciMeas repetitions (incre
# WSSMGN  = '0'                  / WFS gain (0)
# WSCNORFN= '24NIRSPAO-N2x2.cog' / Name of origin vec file
# WCDTSTAT= 'CLOSED_WFS'         / Status of down tt loop
# WCDMSTAT= 'CLOSED'             / Status of DM loop
# WCUTSTAT= 'OPEN'               / Status of utt loop
# DTCLP   = 'CLOSE'              / OPEN/CLOSE TT CLMP ctrl loop
# UTCLP   = 'CLOSE'              / OPEN/CLOSE TT CLMP ctrl loop
# UTGAIN  = '0.000'              / Set TT loop gain
# INSTRUME= 'NIRSPEC'            / Added by KOA
# COMMENT KOA DQA generated keywords follow...
# COMMENT
# COMMENT = 'Script is finished' / Comment
# UTC     = '06:58:46.00'        / coordinated universal time (h)
# UT      = '06:58:46.00'        / Duplicate of UTC (added by KOA)
# ELAPTIME=                  5.0 / Duplicate of ITIME2 (added by KOA)
# FRAMENO =                   45 / Duplicate of FILENUM2 (added by KOA)
# COADD   =                    1 / Duplicate of COADDS2 (added by KOA)
# BLANK   =               -32768 / Keyword added by KOA software
# CRASH   = 'No'                 / NIRSPEC server crash detected?
# KOAID   = 'NC.20170710.25126.fits' / KOA data file name
# IMAGETYP= 'object'             / KOA data file image type
# DATLEVEL=                    0 / Data reduction level
# DQA_DATE= '2017-07-10T19:37:46' / Date of DQA run
# DQA_VERS= '3-2-0'              / DQA version number
# DETMODE = 'scam'               / Detector mode (spec or scam)
# DETGAIN =                    4 / Detector gain
# DETRN   =                   25 / Detector read noise
# DISPERS = 'null'               / NIRSPEC dispersion level
# DISPSCAL= 'null'               / NIRSPEC pixel scale, dispersion (arcsec/pixel)
# GUIDFWHM=                1.355 / FWHM of NIRSPEC guide star
# GUIDTIME= '06:58:44.00'        / UT of logged GUIDFWHM value
# IMAGEMD =                982.0 / Imaging pixels median (DN)
# IMAGEMN =              1252.86 / Imaging pixels mean (DN)
# IMAGESD =               579.14 / Imaging pixels std-dev (DN)
# INSTSTAT=                   -1 / KOA instrument status
# ISAO    = 'yes'                / Is this NIRSPEC-AO data?
# NLINEAR =                   75 / Number of pixels above linearity
# NPIXSAT =                   18 / Number of pixels above saturation
# OA      = 'J.McIlroy'          / Observing assistant
# PROGID  = 'N170'               / WMKO ID for observing program
# PROGINST= 'NASA'               / Program institution
# PROGPI  = 'C.Griffith'         / Program principal investigator
# PROGTL1 = 'What role do Titan' / s Northern Lakes play in the Methane Cycle? ' '
# PROGTL2 = '' / Program title 2
# PROGTL3 = '' / Program title 3
# SEMESTER= '2017A'              / WMKO observing schedule semester
# SIG2NOIS=                 59.0 / Signal-to-noise estimate near image spectral ce
# SLITLEN = 'null'               / Slit length projected on sky (arcsec)
# SLITWIDT= 'null'               / Slit width projected on sky (arcsec)
# SPATSCAL=                0.178 / CCD pixel scale, spatial (arcsec/pixel)
# SPECRES = 'null'               / Nominal spectral resolution
# WAVEBLUE=                 1.43 / Approximate blue end wavelength (u)
# WAVECNTR=                 1.62 / Approximate centralwavelength (u)
# WAVERED =                 1.81 / Approximate red end wavelength (u)
# WXDOMHUM=                  2.4 / Inside dome humidity (%)
# WXDOMTMP=                  4.5 / Inside dome temperature (deg C)
# WXDWPT  =                -43.2 / Dew point temperature (deg C)
# WXOUTHUM=                  1.5 / Outside humidity (%)
# WXOUTTMP=                  4.7 / Outside temperature (deg C)
# WXPRESS =               619.96 / Pressure (mb)
# WXTIME  = '06:58:59.00'        / UT of logged weather keyword values
# WXWNDIR = 'null'               / Wind direction (N through E)
# WXWNDSP = 'null'               / Wind speed (mph)

# %%
# Ask Caitlin: Plate scale?
#scale = 0.178"/pix (then Titan should be ~8 pixels in diameter on scam)
#r_pix = 30-45

# %%
spat_scale = hr_scams[0].header['SPATSCAL']
radius=0.7769
r_pix = radius/spat_scale

print(r_pix)
# Out:
# 4.364606741573034

# %%
plt.plot(np.median(hr_scams[0].data[:,130:140], axis=1))
plt.axvline(x=110, color='r')
plt.axvline(x=162, color='r')

# %%
# TO DO: get accurate r_pix
#for now we'll estimate r_pix = 25. NEED to make this more accurate!

def titan_ortho_coords(img, titan_cen, r_pix=25., alpha=0):
    """ Take a scam image of Titan and convert it to orthographic coordinates.
    img: scam Image
    radius: Titan radius (that night) in arcsec
    """
    
    #spat_scale = hr_scams[0].header['SPATSCAL']
    #r_pix = spat_scale*radius
    
    #get image coordinates [-1:1, disk centered at (a,b) = (0,0)]
    cx,cy = titan_cen[0]
    i,j = np.meshgrid(range(height), range(width))
    a = (j-cy)/25.     
    b = (cx-i)/25.

    #Rotate based on slit angle in scam imaged
    if alpha != 0:
        alpha = np.radians(90-alpha)
        rot_matrix = np.array(( (np.cos(alpha), -np.sin(alpha)),
                        (np.sin(alpha),  np.cos(alpha)) ))

        rotA = np.einsum('ji, mni -> jmn', rot_matrix, np.dstack([a,b]))
        b_ = rotA[0]
        a_ = rotA[1]
        
    return a_,b_

# %%
def slit_ortho_coords(img, titan_cen, alpha, r_pix=25.):
    """ Return orthonormal coordinates of top and bottom of slit (on Titan's disk)."""
    #Find intersection (edge of titan and slit)
    m = np.tan(np.radians(90-alpha))
    slity, slitx = img.header['SLITX'], img.header['SLITY']
    b =slity - m*slitx

    cx,cy = titan_cen[0]

    d = np.sqrt(((r_pix**2)*(1+m**2) - (cx-m*cy-b)**2))
    x1, y1 = (cy+cx*m-b*m + d)/(1+m**2), (b+cy*m+cx*(m**2) +m*d)/(1+m**2)
    x2, y2 = (cy+cx*m-b*m - d)/(1+m**2), (b+cy*m+cx*(m**2) -m*d)/(1+m**2)
    
    
    rot_matrix = np.array(( (np.cos(np.radians(90-alpha)), -np.sin(np.radians(90-alpha))),
                        (np.sin(np.radians(90-alpha)),  np.cos(np.radians(90-alpha))) ))

    rot1 = np.einsum('ji, mni -> jmn', rot_matrix, np.dstack([(x1-cy)/25.,(cx-y1)/25.]))
    nx1 = rot1[0]
    ny1= rot1[1]

    rot2 = np.einsum('ji, mni -> jmn', rot_matrix, np.dstack([(x2-cy)/25.,(cx-y2)/25.]))
    nx2 = rot2[0]
    ny2= rot2[1]

    return (nx1,ny1), (nx2,ny2)

# %%
i = 0

alpha = hr_scams[i].header['SLITANG']
a,b = titan_ortho_coords(hr_scams[i], titan_loc[i], alpha=alpha)

(x1,y1), (x2,y2) = slit_ortho_coords(hr_scams[i], titan_loc[i], alpha=alpha, r_pix=25.)

# %%
# %matplotlib inline
fig= plt.figure(figsize=(6,6))
plt.pcolormesh(a, b, hr_scams[0].data, vmin=0, vmax=1500)
plt.xlim(-1,1)
plt.ylim(-1,1)
#plt.plot((x1-cy)/25.,(cx-y1)/25. , color='r', markersize=11, zorder=1)
#plt.plot(x2,y2, color='r')
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
plt.imshow(data[0].data, vmin=0, vmax=250)
plt.axhline(y=33,color='r')
plt.axhline(y=66,color='r')

# %% [markdown]
# ## TO DO: find width more exacty for each spectrum

# %%
plt.plot(np.median(data[1].data[:,400:600], axis=1))
plt.axvline(x=32,color='r')
plt.axvline(x=66,color='r')

# %%
first = 32.
last = 66.
h = (last - first) / 2 #bin 2 rows together

ortho_y = [(row/h)*(x1-x2) + x2 for row in range(int(h))] #TO DO: half pixel shift to center
ortho_x = y1[0]*np.ones(len(ortho_y))

# %%
fig = plt.figure(figsize=(15,5))
plt.plot(np.linspace(1.5398, 1.5621, 995, endpoint=True), np.median(data[0].data[50:60,:],axis=0))

# %%
#Loop through and get locations of slit in orthographic coordinates
alpha = hr_scams[0].header['SLITANG']
first = 32.
last = 66.
h = (last - first) / 2 #bin 2 rows together

ortho_ys = []
ortho_xs = []

for i in range(len(data)):

    a,b = titan_ortho_coords(hr_scams[i], titan_loc[i], alpha=alpha)

    (x1,y1), (x2,y2) = slit_ortho_coords(hr_scams[i], titan_loc[i], alpha=alpha, r_pix=25.)
    
    ortho_y = [(row/h)*(x1-x2) + x2 for row in range(int(h))] #TO DO: half pixel shift to center
    ortho_x = y1[0]*np.ones(len(ortho_y))  
    
    ortho_ys.append(ortho_y)
    ortho_xs.append(ortho_x)

# %%
#Sum all wavelengths to get something to plot (initally)
intensities = []

for k in range(len(data)):
    intensity = []
    for row in np.arange(32,66, step=2):
        intensity.append(np.sum(np.median(data[k].data[row:row+2,:],axis=0)))
    intensities.append(intensity)
    
intensities = np.array(intensities)

# %%
wave = np.linspace(1.5398, 1.5621, 995, endpoint=True)

# %%
#Sum all wavelengths to get something to plot (initally)
intensities_1.55 = []

for k in range(len(data)):
    intensity = []
    for row in np.arange(32,66, step=2):
        intensity.append(np.sum(np.median(data[k].data[row:row+2,:],axis=0)))
    intensities.append(intensity)
    
intensities = np.array(intensities)

# %%
def get_corners_from_cen(ortho_x, ortho_y):
    x_delta = 1/(0.8/0.041) #Based on slit width
    new_xs = np.array([[x - x_delta, x + x_delta] for x in ortho_x])

    y_delta = (ortho_y[1] - ortho_y[0])/2. #Calculated from y centers
    ortho_y = ortho_y - 2*y_delta
    new_ys = np.array([[y + y_delta, y+y_delta] for y in ortho_y])#.reshape((17,2))
    
    return new_xs, new_ys

# %%
from PIL import Image
titan = Image.open('Titan_mosaic.tif')
titan = np.array(titan)

# %%
plt.imshow(titan, cmap='gray')

# %%
import cartopy.crs as ccrs
ortho = ccrs.Orthographic(central_longitude=0.0, central_latitude=26.6)
earth_r = ortho._x_limits[1]

# The projection keyword determines how the plot will look
plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ortho)#ccrs.PlateCarree())

#ax.pcolormesh(new_a*earth_r, new_b*earth_r, intensity, transform=ccrs.Orthographic())
#ax.pcolormesh(ortho_xs[0]*earth_r, 
#              np.array(ortho_ys[0]).flatten()*earth_r, 
#              intensities[0], transform=ortho)
#Plot Titan Tif
img_extent = (-180, 180, -90, 90)
ax.imshow(titan, origin='upper', extent=img_extent, cmap='gray', transform=ccrs.PlateCarree())


for i in range(len(data)):
    x,y = get_corners_from_cen(ortho_xs[i], 1.2*np.array(ortho_ys[i]).flatten())
    ax.pcolormesh(x*earth_r, y*earth_r, 
              intensities[i].reshape((17,1)), transform=ortho, alpha=0.5)

   # ax.coastlines()
ax.set_global()
plt.show()

# %%
import cartopy.crs as ccrs
ortho = ccrs.Orthographic(central_longitude=0.0, central_latitude=26.6)
earth_r = ortho._x_limits[1]

# The projection keyword determines how the plot will look
plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ortho)#ccrs.PlateCarree())

img_extent = (-180, 180, -90, 90)
ax.imshow(titan, origin='upper', extent=img_extent, cmap='gray', transform=ccrs.PlateCarree())

ax.set_global()
plt.show()

# %%
import cartopy.crs as ccrs
ortho = ccrs.Orthographic(central_longitude=0.0, central_latitude=26.6)
earth_r = ortho._x_limits[1]

# The projection keyword determines how the plot will look
plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

#ax.pcolormesh(new_a*earth_r, new_b*earth_r, intensity, transform=ccrs.Orthographic())
#ax.pcolormesh(ortho_xs[0]*earth_r, 
#              np.array(ortho_ys[0]).flatten()*earth_r, 
#              intensities[0], transform=ortho)
#Plot Titan Tif
img_extent = (-180, 180, -90, 90)
ax.imshow(titan, origin='upper', extent=img_extent, cmap='gray', transform=ccrs.PlateCarree())


for i in range(len(data)):
    x,y = get_corners_from_cen(ortho_xs[i], 1.2*np.array(ortho_ys[i]).flatten())
    ax.pcolormesh(x*earth_r, y*earth_r, 
              intensities[i].reshape((17,1)), transform=ortho, alpha=0.5)

#ax.coastlines()
ax.set_global()
plt.show()
